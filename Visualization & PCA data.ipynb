# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd
import datetime
import pandas_datareader.data as web
from pandas import Series, DataFrame

# %%
data_folder = r'/content/drive/MyDrive/SVM Model Project/Dataset'
data_file = r'/content/drive/MyDrive/SVM Model Project/Dataset/metadata_breast_dataset.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
Data_Result = pd.read_csv('/content/drive/MyDrive/SVM Model Proejct /Dataset/metadata_breast_dataset.csv')
Data_Result

# %%
Data_GWFT_flen = pd.read_csv('/content/drive/MyDrive/SVM Model Proejct /Dataset/GWFP_flen_range_100_250.csv')
Data_GWFT_short = pd.read_csv('/content/drive/MyDrive/SVM Model Proejct /Dataset/GWFP_short.csv')
Data_GWMD = pd.read_csv('/content/drive/MyDrive/SVM Model Proejct /Dataset/GWMD_short.csv')
Data_TMD = pd.read_csv('/content/drive/MyDrive/SVM Model Proejct /Dataset/TMD_short.csv')
Data_Result = pd.read_csv('/content/drive/MyDrive/SVM Model Proejct /Dataset/metadata_breast_dataset.csv')

# %%
from pylab import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = DataFrame(Data_GWFT_flen)
df1

# %%
LBMB001 = df1.LBMB011
LBMB043 = df1.LBMB043
LBMB198 = df1.LBMB198
LBGS099 = df1.LBGS099
LBGS106 = df1.LBGS106
plot(LBMB001)
plot(LBMB043)
plot(LBMB198)
plot(LBGS099)
plot(LBGS106)

# %%
df2 = DataFrame(Data_GWFT_short)
df2 = df2[0:150]
df2

# %%
LBMB001_s = df2.LBMB011
LBMB043_s = df2.LBMB043
LBMB198_s= df2.LBMB198
LBGS099_s= df2.LBGS099
LBGS106_s = df2.LBGS106
plot(LBMB001_s)
plot(LBMB043_s)
plot(LBMB198_s)
plot(LBGS099_s)
plot(LBGS106_s)

# %%
df3 = DataFrame(Data_GWMD)
df3 = df3[0:150]
df3

# %%
LBMB001_3 = df3.LBMB011
LBGS106_3 = df3.LBGS106
plot(LBMB001_3, 'ro')
plot(LBGS106_3, 'b^')

# %%
LBMB001_3 = df3.LBMB011
LBGS106_3 = df3.LBGS106
plot(LBMB001_3, 'r-')
plot(LBGS106_3, 'b-')

# %%
df4 = DataFrame(Data_TMD)
df4 = df4[0:150]
df4
LBMB001_4 = df4.LBMB011
LBGS106_4 = df4.LBGS106
plot(LBMB001_3, 'ro')
plot(LBGS106_3, 'b^')

# %%
df4 = DataFrame(Data_TMD)
df4 = df4[0:150]
df4
LBMB001_4 = df4.LBMB011
LBGS106_4 = df4.LBGS106
plot(LBMB001_3, 'r')
plot(LBGS106_3, 'b')

# %%
Data_Result

#Chuyển Label - số 1, 0
Data_Result["label_number"] =  Data_Result.Label.apply(lambda x: int(x=="cancer"))
Data_Result.head()

# %%
Data_Result.info

# %%
df = DataFrame(Data_Result)
#dfR2 = DataFrame(df1['LBMB011'])
#df = pd.concat([dfR1, dfR2])
#df = df[0:10]
df

# %%
import holoviews as hv
hv.extension('bokeh', logo=False)

scatter = hv.Scatter(df.dropna(), kdims='Age', vdims=[ 'Label'])
scatter.opts(color='Age', size=10, padding=.1, tools=['hover'], colorbar=True, cmap='magma', width=500, height=400, clim=(65,0))

# %%
df = DataFrame(Data_Result)
#dfR2 = DataFrame(df1['LBMB011'])
#dfR2 = dfR2[0:137]
#df = pd.concat([dfR1, dfR2])
df

# %%
Cancer = df[df.Label == 'cancer']
Cancer

# %%
Control = df[df.Label == 'control']
Control.head()

# %%
#Thành lập bộ dữ liệu theo people - các đặc điểm - Label

# %% [markdown]
# DATA PROCESS

# %%
Data_GWFT_flen 
Data_GWFT_short
Data_GWMD 
Data_TMD 
Data_Result

# %%
pd.set_option('display.max_columns', None)

# %%
Data_GWFT_flen_cleaned = Data_GWFT_flen.T.drop("Unnamed: 0")
Data_GWFT_flen_cleaned.columns = ["GWFT_flen_" + str(i) for i in range(151)]
Data_GWFT_flen_cleaned

# %%
Data_GWFT_short_cleaned = Data_GWFT_short.T.drop("bins")
Data_GWFT_short_cleaned.columns = ["GWFT_" + str(i) for i in range(len(Data_GWFT_short_cleaned.columns))]
Data_GWFT_short_cleaned
# Out:
#         GWFT_0 GWFT_1 GWFT_2 GWFT_3 GWFT_4 GWFT_5 GWFT_6 GWFT_7 GWFT_8 GWFT_9  \
# LBMB011   6406   5728   6272   5390   5250   5298   6068   5710   6672    648
# LBMB043  14820  12998  12936  11446  11678  10958  13592  13036  15166   1442
# LBMB198  15934  15112  15512  13724  14252  14128  15668  14842  16272   1386
# LBMB200   8800   8138   8046   6988   7406   6888   8072   8086   9407    761
# LBMB203  16490  15526  15982  14684  14444  13636  15684  15106  16662   1620
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# LBGS099   5396   4038   4348   3534   3544   3414   4354   4416   5554    552
# LBGS106   6240   4877   5034   4132   4402   4110   5064   5026   6078    696
# LBGS109   5254   4432   4564   3804   3774   3722   4390   4264   5476    514
# CRCC12    2876   2558   2648   2156   2304   2232   2730   2582   2906    310
# LBGS111   5926   4578   4794   3944   4014   3930   4772   4696   6136    674
#
#         GWFT_10 GWFT_11 GWFT_12 GWFT_13 GWFT_14 GWFT_15 GWFT_16 GWFT_17  \
# LBMB011    5420    5516    5184    6022    4926    6032    4644    4992
# LBMB043   11422   11826   11014   12710   11188   11816   10178   10808
# LBMB198   13948   14252   13926   15222   13348   16472   11846   13048
# LBMB200    7018    7192    6903    7969    6778    7260    6272    6770
# LBMB203   14038   14538   14094   15458   13268   16472   12124   13404
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# LBGS099    3552    3514    3464    4328    3500    3668    3242    3382
# LBGS106    3986    4342    4004    4892    4176    4936    3868    3934
# LBGS109    3796    3910    3612    4426    3750    4230    3414    3692
# CRCC12     2084    2268    2110    2584    2124    2246    2076    2060
# LBGS111    4042    3950    3904    4676    3868    5554    3936    3816
#
#         GWFT_18 GWFT_19 GWFT_20 GWFT_21 GWFT_22 GWFT_23 GWFT_24 GWFT_25  \
# LBMB011    5932    5198    6060    5060    5998    5160    5046    4740
# LBMB043   12942   10922   12946    9746   13078   11410   10892   10562
# LBMB198   15184   14170   14958   13208   14970   13962   12800   12130
# LBMB203    16706     3620    14490    14310    14022    14082    13568
# ...          ...      ...      ...      ...      ...      ...      ...
# LBGS099     5804     1320     3450     3034     3142     3286     3468
# LBGS106     6262     1454     4336     4044     3948     4186     4152
# LBGS109     5552     1330     4008     3584     3592     3540     3576
# CRCC12      2892      632     2294     2170     2016     2112     2164
# LBGS111     6098     1638     4144     3534     3524     3892     4162
#
#         GWFT_575 GWFT_576 GWFT_577 GWFT_578 GWFT_579 GWFT_580 GWFT_581  \
# LBMB011     3738     3524     2762     6132     2570     2662     3708
# LBMB043     8120     7688     5804    13286     5324     5490     7528
# LBMB198     9568     8836     7158    15372     6732     6916     9654
# LBMB200     5384     4806     3532     8492     3134     3382     5004
# LBMB203    10006     8906     7166    15276     6996     7278     9726
# ...          ...      ...      ...      ...      ...      ...      ...
# LBGS099     2926     2682     1858     4554     1416     1554     2298
# LBGS106     3212     2908     2274     5104     1892     2044     2916
# LBGS109     2874     2752     1866     4694     1772     1672     2530
# CRCC12      1726     1502     1158     2618      982     1062     1484
# LBGS111     3210     2758     2090     4974     1722     1828     2668
#
#         GWFT_582 GWFT_583 GWFT_584 GWFT_585 GWFT_586 GWFT_587
# LBMB011     3492     2582     2478     2690     3108     4202
# LBMB043     6940     5454     5326     5642     6690     8596
# LBMB198     8886     7212     6728     7044     8446    10572
# LBMB200     4726     3240     3392     3730     4214     5746
# LBMB203     9136     6898     7234     7086     8216    10234
# ...          ...      ...      ...      ...      ...      ...
# LBGS099     2256     1516     1590     1652     2268     3238
# LBGS106     2790     2116     1928     2074     2730     3584
# LBGS109     2232     1830     1828     1880     2366     3292
# CRCC12      1432      992     1094     1084     1242     1926
# LBGS111     2582     1772     1808     2008     2598     3672
#
# [137 rows x 588 columns]

# %%
Data_GWMD_cleaned = Data_GWMD.T.drop("bins")
Data_GWMD_cleaned.columns = ["GWMD_" + str(i) for i in range(len(Data_GWMD_cleaned.columns))]
Data_GWMD_cleaned

# %%
Data_TMD_cleaned = Data_TMD.T.drop("region")
Data_TMD_cleaned.columns = ["TMD_" + str(i) for i in range(len(Data_TMD_cleaned.columns))]
Data_TMD_cleaned

# %%
Data_Result["label_number"] =  Data_Result.Label.apply(lambda x: int(x=="cancer"))
Data_Result_cleaned = Data_Result.set_index("SampleID").drop("Unnamed: 0", axis=1)
Data_Result_cleaned = Data_Result_cleaned.rename_axis(index=None)
Data_Result_cleaned

# %%
list_df = [
           Data_GWFT_flen_cleaned,
           Data_GWFT_short_cleaned,
           Data_GWMD_cleaned,
           Data_TMD_cleaned,
           Data_Result_cleaned
]

# %%
df_data_full = None
for df in list_df:
    if df_data_full is not None:
        df_data_full = df_data_full.join(df)
    else:
        df_data_full = df

# %%
df_data_full

# %%
from google.colab import drive

drive.mount('/content/drive')
path = '/content/drive/MyDrive/SVM Model Proejct /Dataset/Datafull.csv'

with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_data_full.to_csv(f)

# %%
df_data_full.describe()

# %%
df_data_full.info()

# %%
import seaborn as sns

# %matplotlib inline
sns.set_style('whitegrid')
sns.countplot(df_data_full['label_number'], label = "Count")

# %%
sns.heatmap(df_data_full.isnull(),yticklabels=False,cbar=True,cmap='viridis')

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x = 'GWMD_10', y = 'GWFT_50', hue = 'label_number', data = df_data_full)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

def print_score(clf, X1_train, y1_train, X1_test, y1_test, train=True):
    if train:
        pred = clf.predict(X1_train)
        clf_report = pd.DataFrame(classification_report(y1_train, pred, output_dict=True))
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(y1_train, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y1_train, pred)}\n")
        
    elif train==False:
        pred = clf.predict(X1_test)
        clf_report = pd.DataFrame(classification_report(y1_test, pred, output_dict=True))
        print("Test Result:\n================================================")        
        print(f"Accuracy Score: {accuracy_score(y1_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y1_test, pred)}\n")

# %% [markdown]
# THU DU DOAN KHI CHUA DUNG PCA

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler

X1 = Data_GWFT_flen_cleaned
y1 = Data_Result_cleaned.label_number

scaler = StandardScaler()
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.3, random_state=42)

X1_train = scaler.fit_transform(X1_train)
X1_test = scaler.transform(X1_test)

# %%
from sklearn.svm import LinearSVC

model = LinearSVC(loss='hinge', dual=True)
model.fit(X1_train, y1_train)

print_score(model, X1_train, y1_train, X1_test, y1_test, train=True)
print_score(model, X1_train, y1_train, X1_test, y1_test, train=False)

# %% [markdown]
# PCA DATA GWFT_flen

# %%
X_GWFTflen = df1_cleaned = Data_GWFT_flen_cleaned
y = df_data_full['label_number']
X_GWFTflen

# %%
X = df1_cleaned
y = df_data_full['label_number']

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler = StandardScaler()
scaler.fit(X_GWFTflen)
X_GWFTflen_scaler = scaler.transform(X_GWFTflen)

# %%
from sklearn.decomposition import PCA

pca_136 = PCA(n_components=136, random_state = 2020) #K<D nen can set n_compon = K = 136
pca_136.fit(X_GWFTflen_scaler)
X_pca_136 = pca_136.transform(X_GWFTflen_scaler)

print('Variance explained by all 30 principal component =',
      sum(pca_136.explained_variance_ratio_ *100))

# %%
pca_136.explained_variance_ratio_ *100

# %% [markdown]
# - TP dau tien ghi lai duoc 81% su thay doi trong tap data
# - TP thu 2 ghi lai 11.5%

# %%
np.cumsum(pca_136.explained_variance_ratio_ *100)

# %%
import matplotlib.pyplot as plt

plt.plot(np.cumsum(pca_136.explained_variance_ratio_ *100))

# %%
pca_2 = PCA(n_components=2, random_state = 2020)
pca_2.fit(X_GWFTflen_scaler)
X_GWFTflen_pca_2 = pca_2.transform(X_GWFTflen_scaler)

# %%
plt.figure(figsize = (10,7))
sns.scatterplot(x = X_GWFTflen_pca_2[:,1],y = X_GWFTflen_pca_2[:,0], s = 70, hue = Data_Result_cleaned.label_number, palette = ['green', 'blue'])

# %%
pca_3 = PCA(n_components=3, random_state = 2020)
pca_3.fit(X_GWFTflen_scaler)
X_GWFTflen_pca_3 = pca_3.transform(X_GWFTflen_scaler)

# %%
from mpl_toolkits import mplot3d

#fig = plt.figure(figzise = (12,8))
ax = plt.axes(projection = '3d')

sctt = ax.scatter3D(X_GWFTflen_pca_3[:,0],X_GWFTflen_pca_3[:,1],X_GWFTflen_pca_3[:,2] , c = Data_Result_cleaned.label_number, s = 50, alpha = 0.6)

# %% [markdown]
# Giu lai 95% data

# %%
pca_95 = PCA(n_components=0.95, random_state = 2020)
pca_95.fit(X_GWFTflen_scaler)
X_GWFTflen_pca_95 = pca_95.transform(X_GWFTflen_scaler)
X_GWFTflen_pca_95.shape

# %% [markdown]
# n_components=3 thi thong tin data duoc giu lai 95%

# %%
df_GWFT_flen_new = pd.DataFrame(X_GWFTflen_pca_95 ,columns = ['GWFT_flen_PCA1', 'GWFT_flen_PCA2', 'GWFT_flen_PCA3'])
#df_GWFT_flen_new['label'] = Data_Result_cleaned.label_number
df_GWFT_flen_new.head()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

def print_score(clf, X_train, y_train, X_test, y_test, train=True):
    if train:
        pred = clf.predict(X_train)
        clf_report = pd.DataFrame(classification_report(y_train, pred, output_dict=True))
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(y_train, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_train, pred)}\n")
        
    elif train==False:
        pred = clf.predict(X_test)
        clf_report = pd.DataFrame(classification_report(y_test, pred, output_dict=True))
        print("Test Result:\n================================================")        
        print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_test, pred)}\n")

# %% [markdown]
# Linear Kernel SVM

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler

X = df_GWFT_flen_new
y = Data_Result_cleaned.label_number

scaler = StandardScaler()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.svm import LinearSVC

model = LinearSVC(loss='hinge', dual=True)
model.fit(X_train, y_train)

print_score(model, X_train, y_train, X_test, y_test, train=True)
print_score(model, X_train, y_train, X_test, y_test, train=False)

# %% [markdown]
# TH2: Polynomial Kernel SVM
# This code trains a SVM classifier using 2rd degree ploynomial kernel.

# %%
from sklearn.svm import SVC

# The hyperparameter coef0 controls how much the model is influenced by high degree ploynomials 
model = SVC(kernel='poly', degree=2, gamma='auto', coef0=1, C=5)
model.fit(X_train, y_train)

print_score(model, X_train, y_train, X_test, y_test, train=True)
print_score(model, X_train, y_train, X_test, y_test, train=False)

# %% [markdown]
# Ti le du doan da duoc nang len 76.2%

# %% [markdown]
# Radial Kernel SVM

# %%
model = SVC(kernel='rbf', gamma=0.5, C=0.1)
model.fit(X_train, y_train)

print_score(model, X_train, y_train, X_test, y_test, train=True)
print_score(model, X_train, y_train, X_test, y_test, train=False)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'C': [0.01, 0.1, 0.5, 1, 10, 100], 
              'gamma': [1, 0.75, 0.5, 0.25, 0.1, 0.01, 0.001], 
              'kernel': ['rbf', 'poly', 'linear']} 

grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=1, cv=5)
grid.fit(X_train, y_train)

best_params = grid.best_params_
print(f"Best params: {best_params}")

svm_clf = SVC(**best_params)
svm_clf.fit(X_train, y_train)
print_score(svm_clf, X_train, y_train, X_test, y_test, train=True)
print_score(svm_clf, X_train, y_train, X_test, y_test, train=False)

# %%
from sklearn.svm import SVC

# The hyperparameter coef0 controls how much the model is influenced by high degree ploynomials 
model = SVC(kernel='poly', degree=2, gamma='auto', coef0=1, C=5)
model.fit(X1_train, y1_train)

print_score(model, X1_train, y1_train, X1_test, y1_test, train=True)
print_score(model, X1_train, y1_train, X1_test, y1_test, train=False)

# %% [markdown]
# USE GWMD data

# %%
X2 = Data_GWMD_cleaned
y = df_data_full['label_number']

from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler = StandardScaler()
scaler.fit(X2)
X2_scaler = scaler.transform(X2)

from sklearn.decomposition import PCA

pca_30_2 = PCA(n_components=136, random_state = 2020) #K<D nen can set n_compon = K = 136
pca_30_2.fit(X2_scaler)
X_pca_30_2 = pca_30_2.transform(X2_scaler)

print('Variance explained by all 30 principal component =',
      sum(pca_30_2.explained_variance_ratio_ *100))

# %%
pca_30_2.explained_variance_ratio_ *100
np.cumsum(pca_30_2.explained_variance_ratio_ *100)
import matplotlib.pyplot as plt

plt.plot(np.cumsum(pca_30_2.explained_variance_ratio_ *100))

# %% [markdown]
# Lay n = 18 giu dc 87% thong tin du lieu

# %%
pca_95_2 = PCA(n_components=0.95, random_state = 2020)
pca_95_2.fit(X2_scaler)
X2_pca_95 = pca_95_2.transform(X2_scaler)
X2_pca_95.shape

# %%
#Muon co dc 95% thong tin du lieu can 67 cot?

# %%
df_GWMD_new = pd.DataFrame(X2_pca_95)
#df_GWFT_flen_new['label'] = Data_Result_cleaned.label_number
df_GWMD_new.head()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

def print_score(clf, X2_train, y2_train, X2_test, y2_test, train=True):
    if train:
        pred = clf.predict(X2_train)
        clf_report = pd.DataFrame(classification_report(y2_train, pred, output_dict=True))
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(y2_train, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y2_train, pred)}\n")
        
    elif train==False:
        pred = clf.predict(X2_test)
        clf_report = pd.DataFrame(classification_report(y2_test, pred, output_dict=True))
        print("Test Result:\n================================================")        
        print(f"Accuracy Score: {accuracy_score(y2_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y2_test, pred)}\n")

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler

X2 = df_GWMD_new
y2 = Data_Result_cleaned.label_number

scaler = StandardScaler()
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.3, random_state=42)

X2_train = scaler.fit_transform(X2_train)
X2_test = scaler.transform(X2_test)

# %%
from sklearn.svm import LinearSVC

model = LinearSVC(loss='hinge', dual=True)
model.fit(X2_train, y2_train)

print_score(model, X2_train, y2_train, X2_test, y2_test, train=True)
print_score(model, X2_train, y2_train, X2_test, y2_test, train=False)

# %%
from sklearn.svm import SVC

# The hyperparameter coef0 controls how much the model is influenced by high degree ploynomials 
model = SVC(kernel='poly', degree=2, gamma='auto', coef0=1, C=5)
model.fit(X2_train, y2_train)

print_score(model, X2_train, y2_train, X2_test, y2_test, train=True)
print_score(model, X2_train, y2_train, X2_test, y2_test, train=False)

# %%
param_grid = {'C': [0.01, 0.1, 0.5, 1, 10, 100], 
              'gamma': [1, 0.75, 0.5, 0.25, 0.1, 0.01, 0.001], 
              'kernel': ['rbf', 'poly', 'linear']} 

grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=1, cv=5)
grid.fit(X2_train, y2_train)
best_params = grid.best_params_
print(f"Best params: {best_params}")

svm_clf = SVC(**best_params)
svm_clf.fit(X2_train, y2_train)

print_score(svm_clf, X2_train, y2_train, X2_test, y2_test, train=True)
print_score(svm_clf, X2_train, y2_train, X2_test, y2_test, train=False)

# %% [markdown]
# TMD DATA

# %%
X3 = Data_TMD_cleaned
y3 = df_data_full['label_number']

from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler = StandardScaler()
scaler.fit(X3)
X3_scaler = scaler.transform(X3)

from sklearn.decomposition import PCA

pca_30_TMD= PCA(n_components=136, random_state = 2020) #K<D nen can set n_compon = K = 136
pca_30_TMD.fit(X3_scaler)
X_pca_30_TMD = pca_30_TMD.transform(X3_scaler)

print('Variance explained by all 30 principal component =',
      sum(pca_30_TMD.explained_variance_ratio_ *100))

# %%
pca_30_TMD.explained_variance_ratio_ *100
np.cumsum(pca_30_TMD.explained_variance_ratio_ *100)
import matplotlib.pyplot as plt

plt.plot(np.cumsum(pca_30_TMD.explained_variance_ratio_ *100))

# %%
pca_95_TMD = PCA(n_components=0.95, random_state = 2020)
pca_95_TMD.fit(X3_scaler)
X3_pca_95 = pca_95_TMD.transform(X3_scaler)
X3_pca_95.shape

# %%
df_TMD_new = pd.DataFrame(X3_pca_95)
#df_GWFT_flen_new['label'] = Data_Result_cleaned.label_number
df_TMD_new.head()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

def print_score(clf, X3_train, y3_train, X3_test, y3_test, train=True):
    if train:
        pred = clf.predict(X3_train)
        clf_report = pd.DataFrame(classification_report(y3_train, pred, output_dict=True))
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(y3_train, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y3_train, pred)}\n")
        
    elif train==False:
        pred = clf.predict(X3_test)
        clf_report = pd.DataFrame(classification_report(y3_test, pred, output_dict=True))
        print("Test Result:\n================================================")        
        print(f"Accuracy Score: {accuracy_score(y3_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y3_test, pred)}\n")

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler

X3 = df_TMD_new
y3 = Data_Result_cleaned.label_number

scaler = StandardScaler()
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size=0.3, random_state=42)

X3_train = scaler.fit_transform(X3_train)
X3_test = scaler.transform(X3_test)

# %%
from sklearn.svm import LinearSVC

model = LinearSVC(loss='hinge', dual=True)
model.fit(X3_train, y3_train)

print_score(model, X3_train, y3_train, X3_test, y3_test, train=True)
print_score(model, X3_train, y3_train, X3_test, y3_test, train=False)

# %%
from sklearn.svm import SVC

# The hyperparameter coef0 controls how much the model is influenced by high degree ploynomials 
model = SVC(kernel='poly', degree=2, gamma='auto', coef0=1, C=5)
model.fit(X3_train, y3_train)

print_score(model, X3_train, y3_train, X3_test, y3_test, train=True)
print_score(model, X3_train, y3_train, X3_test, y3_test, train=False)

# %%
param_grid = {'C': [0.01, 0.1, 0.5, 1, 10, 100], 
              'gamma': [1, 0.75, 0.5, 0.25, 0.1, 0.01, 0.001], 
              'kernel': ['rbf', 'poly', 'linear']} 

grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=1, cv=5)
grid.fit(X3_train, y3_train)
best_params = grid.best_params_
print(f"Best params: {best_params}")

svm_clf = SVC(**best_params)
svm_clf.fit(X3_train, y3_train)

print_score(svm_clf, X3_train, y3_train, X3_test, y3_test, train=True)
print_score(svm_clf, X3_train, y3_train, X3_test, y3_test, train=False)

# %% [markdown]
# USE ALL DATA

# %%
df_data_full.columns

# %%
df_data_full.null()

# %%
yR = y = Data_Result_cleaned.label_number

# %%
#df_GWFT_flen_new = DataFrame(df_GWFT_flen_new)
#df_GWMD_new = DataFrame(df_GWMD_new)
#df_TMD_new = DataFrame(df_TMD_new)

df_data_PCA = pd.concat([df_GWFT_flen_new,df_GWMD_new,df_TMD_new])
df_data_PCA

# %%
list_df_PCA = [
           X,
           X2,
           X3,
           Data_Result_cleaned
]

# %%
df_data_PCA = None
for df in list_df:
    if df_data_PCA is not None:
        df_data_full = df_data_PCA.join(df)
    else:
        df_data_PCA = df

# %%
 df_data_PCA

# %%
XR
yR 

from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler = StandardScaler()
scaler.fit(XR)
XR_scaler = scaler.transform(XR)

from sklearn.decomposition import PCA

pca_30_R = PCA(n_components=136, random_state = 2020) #K<D nen can set n_compon = K = 136
pca_30_R.fit(XR_scaler)
X_pca_30_R = pca_30_R.transform(XR_scaler)

print('Variance explained by all 30 principal component =',
      sum(pca_30_R.explained_variance_ratio_ *100))
